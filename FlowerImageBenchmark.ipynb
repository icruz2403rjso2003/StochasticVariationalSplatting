# %%
import sys

sys.dont_write_bytecode = True

# %%
from sklearn.datasets import load_sample_image

import matplotlib.pyplot as plt

from ImageToPatches import ImageToPatches

# %%
flower = load_sample_image('flower.jpg')

# %%
plt.figure(figsize = (15, 7.5))

plt.imshow(flower, aspect = 'auto')

plt.axis('off')

plt.show()

# %%
ITP = ImageToPatches(image = flower, patch_size = 100)

ITP.image_to_patches()

# %%
print('Pixels da Imagem:\n')

print(ITP.pixel)
# Out:
# Pixels da Imagem:
#
# [[0.         0.        ]
#  [0.         0.00156495]
#  [0.         0.00312989]
#  ...
#  [1.         0.99687011]
#  [1.         0.99843505]
#  [1.         1.        ]]

# %%
print('Cores da Imagem:\n')

print(ITP.color)
# Out:
# Cores da Imagem:
#
# [[0.00784314 0.08296943 0.06598985]
#  [0.01176471 0.07860262 0.06598985]
#  [0.02745098 0.08733624 0.06598985]
#  ...
#  [0.02745098 0.20087336 0.14213198]
#  [0.03137255 0.19650655 0.14213198]
#  [0.03529412 0.18777293 0.13705584]]

# %%
plt.figure(figsize = (15, 7.5))

plt.imshow(ITP.color.reshape((ITP.H, ITP.W, 3)), aspect = 'auto')

plt.axis('off')

plt.show()

# %%
print(ITP.pixel_patches.shape)
# Out:
# (5, 7, 100, 2)

# %%
print(ITP.color_patches.shape)
# Out:
# (5, 7, 100, 3)

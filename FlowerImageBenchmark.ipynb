# %%
import sys

sys.dont_write_bytecode = True

# %%
from sklearn.datasets import load_sample_image

import matplotlib.pyplot as plt

from ImageToPatches import image_to_patches

import jax.numpy as jnp

# %%
flower = load_sample_image('flower.jpg')

# %%
plt.figure(figsize = (15, 7.5))

plt.imshow(flower, aspect = 'auto')

plt.axis('off')

plt.show()

# %%
pixel_patches, color_patches = image_to_patches(

    image = jnp.array(flower), 
    
    patch_size = 100

)

# %%
print(pixel_patches.shape)
# Out:
# (5, 7, 10000, 2)

# %%
print(color_patches.shape)
# Out:
# (5, 7, 10000, 3)
